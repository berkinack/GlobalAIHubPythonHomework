# %%
name=input("Name:")
surname=input("Surname:")
age=int(input("Age:"))
dob=int(input("Date of birth:"))
list=(name,surname,age,dob)
for i in list:
    print(i)
if age<18: 
    print("You can't go out because it's too dangerous")
elif age>18: 
    print("You can go out to the street")
# Out:
# Name:berkin
# Surname:açıkgöz
# Age:19
# Date of birth:2001
# berkin
# açıkgöz
# 19
# 2001
# You can go out to the street
