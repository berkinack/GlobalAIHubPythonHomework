# %%
s1=int(input("1.sayıyı giriniz:"))
s2=int(input("2.sayıyı giriniz:"))
s3=int(input("3.sayıyı giriniz:"))
s4=int(input("4.sayıyı giriniz:"))
s5=int(input("5.sayıyı giriniz:"))
print(f"""1.sayı={s1}
2.sayı={s2} 
3.sayı={s3} 
4.sayı={s4} 
5.sayı={s5}""")
# Out:
# 1.sayıyı giriniz: 9
# 2.sayıyı giriniz: 3
# 3.sayıyı giriniz: 6
# 4.sayıyı giriniz: 4
# 5.sayıyı giriniz: 7
# 1.sayı=9
# 2.sayı=3
# 3.sayı=6
# 4.sayı=4
# 5.sayı=7

# %%
s=13
ad="Berkin"
boy=1.76
print(f"s={type(s)}")
print(f"ad={type(ad)}")
print("boy={0}".format(type(boy)))
# Out:
# s=<class 'int'>
# ad=<class 'str'>
# boy=<class 'float'>

# %%
list=(1,3,6,"b",1.9)
list
# Out:
# (1, 3, 6, 'b', 1.9)

# %%
s=[ ]
for i in range(5):
    s.append(int(input("Sayı giriniz:")))
for i in s:
    print(i)
# Out:
# Sayı giriniz: 8
# Sayı giriniz: 6
# Sayı giriniz: 9
# Sayı giriniz: 3
# Sayı giriniz: 7
# 8
# 6
# 9
# 3
# 7
